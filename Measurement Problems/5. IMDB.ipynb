# %% [markdown]
# # IMDB Film Puanlama ve Sıralama (IMDB Scoring and Sorting)

# %%
import pandas as pd 
import math
import scipy.stats as st

# %%
df = pd.read_csv("datasets/movies_metadata.csv", low_memory=False)
#DtypeWarning kapamak için

# %%
df = df[["title", "vote_average", "vote_count"]]

# %%
df.head()
# Out:
#                          title  vote_average  vote_count
# 0                    Toy Story           7.7      5415.0
# 1                      Jumanji           6.9      2413.0
# 2             Grumpier Old Men           6.5        92.0
# 3            Waiting to Exhale           6.1        34.0
# 4  Father of the Bride Part II           5.7       173.0

# %%
df.shape
#45466tane film var
# Out:
# (45466, 3)

# %%
# Örneğin vote_average a göre bir sıralama yapalım. 
df.sort_values("vote_average", ascending=False).head(20)
#Bu sıralama beklentimizin dışında oldu. Dolayısıyla sadece ortalamaya göre sıralama yapmak mantıklı değil. 
#çünkü vote_count değerleri birbirinden oldukça farklı görülmekte.
# Out:
#                                                  title  vote_average  \
# 21642  Ice Age Columbus: Who Were the First Americans?          10.0
# 15710        If God Is Willing and da Creek Don't Rise          10.0
# 22396                                   Meat the Truth          10.0
# 22395            Marvin Hamlisch: What He Did For Love          10.0
# 35343                       Elaine Stritch: At Liberty          10.0
# 186                                           Reckless          10.0
# 45047                                  The Human Surge          10.0
# 22377                                        The Guide          10.0
# 22346                                   هیچ کجا هیچ کس          10.0
# 1634                          Other Voices Other Rooms          10.0
# 35461                          Tom Brown's School Days          10.0
# 22255                                  Cowboy del Amor          10.0
# 45005                                       Fool's Day          10.0
# 41879                   Panorama of Esplanade by Night          10.0
# 41845                                        Maula Jat          10.0
# 40431                              People of a Feather          10.0
# 40442                              Siccin 3: Cürmü Ask          10.0
# 27908                                           Mentor          10.0
# 41804                                       Bella Vita          10.0
# 41797      Campaign of Hate: Russia and Gay Propaganda          10.0
#
#        vote_count
# 21642         1.0
# 15710         1.0
# 22396         1.0
# 22395         1.0
# 35343         1.0
# 186           1.0
# 45047         1.0
# 22377         1.0
# 22346         1.0
# 1634          1.0
# 35461         1.0
# 22255         1.0
# 45005         1.0
# 41879         1.0
# 41845         1.0
# 40431         1.0
# 40442         2.0
# 27908         1.0
# 41804         1.0
# 41797         1.0

# %%
#Öyleyse vote_count'a bir filtre koyabiliriz. Yani belirli bir sayının üzerinde olanları alabiliriz sadece. 
#Peki bu sayıyı nasıl belirleyeceğiz; 
df["vote_count"].describe([0.10, 0.25, 0.50, 0.70, 0.80, 0.90, 0.95, 0.99]).T
#Filmlerin ortalama oy sayısı 109.897 civarında görünüyor. Yani biz de filtreyi bu ortalamanın üzerinde bir değerde tutabiliriz.
# Bu yüzden 400leri tercih ediyoruz.
# Out:
# count    45460.000000
# mean       109.897338
# std        491.310374
# min          0.000000
# 10%          1.000000
# 25%          3.000000
# 50%         10.000000
# 70%         25.000000
# 80%         50.000000
# 90%        160.000000
# 95%        434.000000
# 99%       2183.820000
# max      14075.000000
# Name: vote_count, dtype: float64

# %%
# Şimdi oy sayısı 400den büyük olanları seçip sıralayalım;
df[df["vote_count"] > 400].sort_values("vote_average", ascending=False).head(20)
# Sadece vote_count a göre filtre koymakta tam anlamıyla doğru mu bilemiyoruz. Bu yüzden daha kombine bir sistem oluşturmalıyız.
# Out:
#                                  title  vote_average  vote_count
# 10309      Dilwale Dulhania Le Jayenge           9.1       661.0
# 40251                       Your Name.           8.5      1030.0
# 834                      The Godfather           8.5      6024.0
# 314           The Shawshank Redemption           8.5      8358.0
# 1152   One Flew Over the Cuckoo's Nest           8.3      3001.0
# 1176                            Psycho           8.3      2405.0
# 1178            The Godfather: Part II           8.3      3418.0
# 292                       Pulp Fiction           8.3      8670.0
# 1184       Once Upon a Time in America           8.3      1104.0
# 5481                     Spirited Away           8.3      3968.0
# 522                   Schindler's List           8.3      4436.0
# 23673                         Whiplash           8.3      4376.0
# 2843                        Fight Club           8.3      9678.0
# 2211                 Life Is Beautiful           8.3      3643.0
# 12481                  The Dark Knight           8.3     12269.0
# 5878                       City of God           8.2      1852.0
# 1170                        GoodFellas           8.2      3211.0
# 1161                      12 Angry Men           8.2      2130.0
# 351                       Forrest Gump           8.2      8147.0
# 39386                            Piper           8.2       487.0

# %%
# Bir minmaxscaler metodu getirip, vote_count değişkenini standartlaştıracağız. 1 ile 10 arasında değerler atamasını bekliyoruz.
from sklearn.preprocessing import MinMaxScaler

# %%
df["vote_count_score"]=MinMaxScaler(feature_range=(1, 10)). \
    fit(df[["vote_count"]]). \
    transform(df[["vote_count"]])

# %%
df
# Out:
#                              title  vote_average  vote_count  vote_count_score
# 0                        Toy Story           7.7      5415.0          4.462522
# 1                          Jumanji           6.9      2413.0          2.542948
# 2                 Grumpier Old Men           6.5        92.0          1.058828
# 3                Waiting to Exhale           6.1        34.0          1.021741
# 4      Father of the Bride Part II           5.7       173.0          1.110622
# ...                            ...           ...         ...               ...
# 45461                       Subdue           4.0         1.0          1.000639
# 45462          Century of Birthing           9.0         3.0          1.001918
# 45463                     Betrayal           3.8         6.0          1.003837
# 45464             Satan Triumphant           0.0         0.0          1.000000
# 45465                     Queerama           0.0         0.0          1.000000
#
# [45466 rows x 4 columns]

# %%
# vote_average değeri ve vote_count_score değerini çarparak average_count_score değeri oluşturuyoruz. 
df["average_count_score"]= df["vote_count_score"] * df["vote_average"]

# %%
#ş imdi ise average_count_score a göre sıralayalım
df.sort_values("average_count_score", ascending=False).head(20)
# ortalama olarak doğru bir sıralama olmuş gibi görünüyor. Tabii bu da yeterli değil.
# Out:
#                                                    title  vote_average  \
# 15480                                          Inception           8.1
# 12481                                    The Dark Knight           8.3
# 22879                                       Interstellar           8.1
# 17818                                       The Avengers           7.4
# 14551                                             Avatar           7.2
# 26564                                           Deadpool           7.4
# 2843                                          Fight Club           8.3
# 20051                                   Django Unchained           7.8
# 23753                            Guardians of the Galaxy           7.9
# 292                                         Pulp Fiction           8.3
# 314                             The Shawshank Redemption           8.5
# 2458                                          The Matrix           7.9
# 4863   The Lord of the Rings: The Fellowship of the Ring           8.0
# 18252                              The Dark Knight Rises           7.6
# 26553                                 Mad Max: Fury Road           7.3
# 351                                         Forrest Gump           8.2
# 7000       The Lord of the Rings: The Return of the King           8.1
# 12588                                           Iron Man           7.4
# 18244                                   The Hunger Games           6.9
# 5814               The Lord of the Rings: The Two Towers           8.0
#
#        vote_count  vote_count_score  average_count_score
# 15480     14075.0         10.000000            81.000000
# 12481     12269.0          8.845187            73.415048
# 22879     11187.0          8.153321            66.041904
# 17818     12000.0          8.673179            64.181528
# 14551     12114.0          8.746075            62.971737
# 26564     11444.0          8.317655            61.550650
# 2843       9678.0          7.188419            59.663879
# 20051     10297.0          7.584227            59.156973
# 23753     10014.0          7.403268            58.485819
# 292        8670.0          6.543872            54.314139
# 314        8358.0          6.344369            53.927140
# 2458       9079.0          6.805400            53.762657
# 4863       8892.0          6.685826            53.486607
# 18252      9263.0          6.923055            52.615218
# 26553      9629.0          7.157087            52.246735
# 351        8147.0          6.209449            50.917485
# 7000       8226.0          6.259964            50.705712
# 12588      8951.0          6.723552            49.754288
# 18244      9634.0          7.160284            49.405961
# 5814       7641.0          5.885897            47.087176

# %% [markdown]
# # IMDB Ağırlıklı Derecelendirme (IMDB Weighted Rating)

# %% [markdown]
# * weighted_rating = (v/(v+M) * r) + (M/(v+M) * C)
# * r = vote average Filmin puanı
# * v = vote count Oy sayısı
# * M = minimum votes required to be listed in the Top 250 Sıralamaya girmek için gerekli olan min oy değeri
# * C = the mean vote across the whole report (currently 7.0) Kitlenin genel ortalaması

# %%
# Formülün ilk kısmında; 
# bir film gerekenden çok oy aldıysa bu filmin puanına uygulanacak olan düzeltmenin şiddeti az olacaktır. 
# bir film gereknden az oy aldıysa bu film listeye giremeyecektir çünkü çok fazla düzeltmeye maruz kalacaktır. 
#Formulün ikinci partında;
#oy sayısı yükseldikçe dezavantaj gibi oluyor, Kitlenin genel ortalaması kritiktir.

# %%
M = 2500
C = df['vote_average'].mean()

def weighted_rating(r, v, M, C):
    return (v / (v + M) * r) + (M / (v + M) * C)

# %%
df.sort_values("average_count_score", ascending=False).head(20)
# Deadpool filmi beklentinin üzerinde bir sırada gibi görünüyor. Bunun için hesaplama yapalım.
# Out:
#                                                    title  vote_average  \
# 15480                                          Inception           8.1
# 12481                                    The Dark Knight           8.3
# 22879                                       Interstellar           8.1
# 17818                                       The Avengers           7.4
# 14551                                             Avatar           7.2
# 26564                                           Deadpool           7.4
# 2843                                          Fight Club           8.3
# 20051                                   Django Unchained           7.8
# 23753                            Guardians of the Galaxy           7.9
# 292                                         Pulp Fiction           8.3
# 314                             The Shawshank Redemption           8.5
# 2458                                          The Matrix           7.9
# 4863   The Lord of the Rings: The Fellowship of the Ring           8.0
# 18252                              The Dark Knight Rises           7.6
# 26553                                 Mad Max: Fury Road           7.3
# 351                                         Forrest Gump           8.2
# 7000       The Lord of the Rings: The Return of the King           8.1
# 12588                                           Iron Man           7.4
# 18244                                   The Hunger Games           6.9
# 5814               The Lord of the Rings: The Two Towers           8.0
#
#        vote_count  vote_count_score  average_count_score
# 15480     14075.0         10.000000            81.000000
# 12481     12269.0          8.845187            73.415048
# 22879     11187.0          8.153321            66.041904
# 17818     12000.0          8.673179            64.181528
# 14551     12114.0          8.746075            62.971737
# 26564     11444.0          8.317655            61.550650
# 2843       9678.0          7.188419            59.663879
# 20051     10297.0          7.584227            59.156973
# 23753     10014.0          7.403268            58.485819
# 292        8670.0          6.543872            54.314139
# 314        8358.0          6.344369            53.927140
# 2458       9079.0          6.805400            53.762657
# 4863       8892.0          6.685826            53.486607
# 18252      9263.0          6.923055            52.615218
# 26553      9629.0          7.157087            52.246735
# 351        8147.0          6.209449            50.917485
# 7000       8226.0          6.259964            50.705712
# 12588      8951.0          6.723552            49.754288
# 18244      9634.0          7.160284            49.405961
# 5814       7641.0          5.885897            47.087176

# %%
# Deadpool'un r değeri; 7.4, v değeri;11444.0, M ve C değerlerini yukarda formülize ettik. 
weighted_rating(7.4, 11444.0, M, C)
# Out:
# 7.080544896574546

# %%
# Şimdi ise Inception için bakalım;
weighted_rating(8.1, 14075.0, M, C)
# Out:
# 7.725672279809078

# %%
# Son olarak The Shawshank Redemption filmini değerlendirelim;
weighted_rating (8.5, 8358.0, M, C)
# Out:
# 7.83648167598411

# %%
# Bu üç değer bizimkinden farklı dağıldı, bunu bütün veriye uygulayalım. 
df["weighted_rating"] = weighted_rating(df["vote_average"],
                                        df["vote_count"], M, C)

df.sort_values("weighted_rating", ascending=False).head(10)
# Out:
#                                                    title  vote_average  \
# 12481                                    The Dark Knight           8.3
# 314                             The Shawshank Redemption           8.5
# 2843                                          Fight Club           8.3
# 15480                                          Inception           8.1
# 292                                         Pulp Fiction           8.3
# 834                                        The Godfather           8.5
# 22879                                       Interstellar           8.1
# 351                                         Forrest Gump           8.2
# 7000       The Lord of the Rings: The Return of the King           8.1
# 4863   The Lord of the Rings: The Fellowship of the Ring           8.0
#
#        vote_count  vote_count_score  average_count_score  weighted_rating
# 12481     12269.0          8.845187            73.415048         7.846044
# 314        8358.0          6.344369            53.927140         7.836482
# 2843       9678.0          7.188419            59.663879         7.749460
# 15480     14075.0         10.000000            81.000000         7.725672
# 292        8670.0          6.543872            54.314139         7.699778
# 834        6024.0          4.851936            41.241456         7.654800
# 22879     11187.0          8.153321            66.041904         7.646688
# 351        8147.0          6.209449            50.917485         7.593775
# 7000       8226.0          6.259964            50.705712         7.521547
# 4863       8892.0          6.685826            53.486607         7.477310

# %%
# Şimdi bizimkini getirelim; 
df.sort_values("average_count_score", ascending=False).head(10)
# Out:
#                          title  vote_average  vote_count  vote_count_score  \
# 15480                Inception           8.1     14075.0         10.000000
# 12481          The Dark Knight           8.3     12269.0          8.845187
# 22879             Interstellar           8.1     11187.0          8.153321
# 17818             The Avengers           7.4     12000.0          8.673179
# 14551                   Avatar           7.2     12114.0          8.746075
# 26564                 Deadpool           7.4     11444.0          8.317655
# 2843                Fight Club           8.3      9678.0          7.188419
# 20051         Django Unchained           7.8     10297.0          7.584227
# 23753  Guardians of the Galaxy           7.9     10014.0          7.403268
# 292               Pulp Fiction           8.3      8670.0          6.543872
#
#        average_count_score  weighted_rating
# 15480            81.000000         7.725672
# 12481            73.415048         7.846044
# 22879            66.041904         7.646688
# 17818            64.181528         7.092794
# 14551            62.971737         6.929405
# 26564            61.550650         7.080545
# 2843             59.663879         7.749460
# 20051            59.156973         7.373769
# 23753            58.485819         7.444152
# 292              54.314139         7.699778

# %% [markdown]
# # Bayesian Average Rating Score (Bar Score)

# %%
# Yukardaki tüm yöntemler 2015 yıllarında gözlemlenmiştir. 
# IMDB'nin sitesinde sıralama değişmiştir. IMDB yeni bir sıralama yöntemi geliştirmiştir. 
# Bu sıralamaya en yakın çıktıyo elde etmek için bayesian average rating deneyeceğiz.

# %%
def bayesian_average_rating(n, confidence=0.95):
    if sum(n) == 0:
        return 0
    K = len(n)
    z = st.norm.ppf(1 - (1 - confidence) / 2)
    N = sum(n)
    first_part = 0.0
    second_part = 0.0
    for k, n_k in enumerate(n):
        first_part += (k + 1) * (n[k] + 1) / (N + K)
        second_part += (k + 1) * (k + 1) * (n[k] + 1) / (N + K)
    score = first_part - z * math.sqrt((second_part - first_part * first_part) / (N + K + 1))
    return score
bayesian_average_rating([34733, 4355, 4704, 6561, 13515, 26183, 87368, 273082, 600260, 1295351])#esaretin bedeli için tüm yıldız sayılarını yazalım. 
# IMDB'deki güncel puan 9.3.
# Out:
# 9.14538444560111

# %%
#Şimdi yukardaki işlemi baba filmi için uygulayalım;
bayesian_average_rating([37128, 5879, 6268, 8419, 16603, 30016, 78538, 199430, 402518, 837905]) #kaç 1 yıldız, kaç 2 yıldız.... kaç 10 yıldız
#Güncel puan 9.2 olarak görülmekte. 
#user Quality i biliyor olsaydık IMDB puanına daha çok yaklaşırdık.
# Out:
# 8.940007324860396

# %%
#Şimdi bütün bunları filmlerin hepsine uygulayalım; 
df= pd.read_csv("/Users/elifbagci/Desktop/Miuul:DATA SCİENCE/Elif Miuul notlar/Measurement Problems/Uygulama- IMDB /dataset/imdb_ratings.csv")
df=df.iloc[0:, 1:]

# %%
df.head()
# Kullandığımız bu yeni verisetinden hangi yıldızın kaç tane aldığını görebiliriz.
# Out:
#        id                                 movieName  rating      ten    nine  \
# 0  111161  1.       The Shawshank Redemption (1994)     9.2  1295382  600284
# 1   68646             2.       The Godfather (1972)     9.1   837932  402527
# 2   71562    3.       The Godfather: Part II (1974)     9.0   486356  324905
# 3  468569           4.       The Dark Knight (2008)     9.0  1034863  649123
# 4   50083              5.       12 Angry Men (1957)     8.9   246765  225437
#
#     eight   seven    six   five   four  three   two    one
# 0  273091   87368  26184  13515   6561   4704  4355  34733
# 1  199440   78541  30016  16603   8419   6268  5879  37128
# 2  175507   70847  26349  12657   6210   4347  3892  20469
# 3  354610  137748  49483  23237  11429   8082  7173  30345
# 4  133998   48341  15773   6278   2866   1723  1478   8318

# %%
df["bar_score"] = df.apply(lambda x: bayesian_average_rating(x[["one", "two", "three", "four", "five",
                                                                "six", "seven", "eight", "nine", "ten"]]), axis=1)
df.sort_values("bar_score", ascending=False).head(20)
# Out:
#          id                                          movieName  rating  \
# 0    111161           1.       The Shawshank Redemption (1994)     9.2
# 1     68646                      2.       The Godfather (1972)     9.1
# 3    468569                    4.       The Dark Knight (2008)     9.0
# 2     71562             3.       The Godfather: Part II (1974)     9.0
# 4     50083                       5.       12 Angry Men (1957)     8.9
# 6    167260  7.       The Lord of the Rings: The Return of ...     8.9
# 5    108052                   6.       Schindler's List (1993)     8.9
# 11   109830                      12.       Forrest Gump (1994)     8.8
# 12  1375666                         13.       Inception (2010)     8.7
# 10   137523                        11.       Fight Club (1999)     8.8
# 7    110912                       8.       Pulp Fiction (1994)     8.8
# 9    120737  10.       The Lord of the Rings: The Fellowshi...     8.8
# 8     60196    9.       Il buono, il brutto, il cattivo (1966)     8.8
# 28   816692                      29.       Interstellar (2014)     8.5
# 13   167261  14.       The Lord of the Rings: The Two Tower...     8.7
# 14    80684  15.       Star Wars: Episode V - The Empire St...     8.7
# 16    99685                        17.       Goodfellas (1990)     8.6
# 17    73486   18.       One Flew Over the Cuckoo's Nest (1975)     8.6
# 20   118799                   21.       La vita è bella (1997)     8.6
# 43  1675434                  44.       The Intouchables (2011)     8.5
#
#         ten    nine   eight   seven    six   five   four  three   two    one  \
# 0   1295382  600284  273091   87368  26184  13515   6561   4704  4355  34733
# 1    837932  402527  199440   78541  30016  16603   8419   6268  5879  37128
# 3   1034863  649123  354610  137748  49483  23237  11429   8082  7173  30345
# 2    486356  324905  175507   70847  26349  12657   6210   4347  3892  20469
# 4    246765  225437  133998   48341  15773   6278   2866   1723  1478   8318
# 6    703093  433087  270113  117411  44760  21818  10873   7987  6554  28990
# 5    453906  383584  220586   82367  27219  12922   6234   4572  4289  19328
# 11   622104  553654  373644  151284  51140  22720  11692   7647  5941  12110
# 12   724798  627987  408686  174229  60668  26910  13436   8703  6932  17621
# 10   637087  572654  371752  152295  53059  24755  12648   8606  6948  17435
# 7    674884  541946  332876  140886  52091  26828  14203  10425  8912  25610
# 9    631020  460809  316221  132929  46699  22658  11002   8295  6911  27013
# 8    246549  199725  138309   58595  18777   8607   3903   2451  2032  10319
# 28   541682  412079  292240  149125  57253  24501  12271   7595  5618  12841
# 13   517453  420229  310443  130399  44743  20787   9690   6815  5851  20950
# 14   400167  317719  248795  111143  36699  15938   6812   4344  3556  15568
# 16   288944  321818  252107  101041  29875  11432   5127   3202  2327   6472
# 17   253488  294955  226631   90925  27027  10438   4679   2510  1936   6587
# 20   198684  189402  133743   55912  19766   9232   4792   3011  2590   7419
# 43   202778  239677  194439   81087  23665   8439   3853   2161  1575   4129
#
#     bar_score
# 0    9.145389
# 1    8.940016
# 3    8.895962
# 2    8.812499
# 4    8.767934
# 6    8.752038
# 5    8.743609
# 11   8.699152
# 12   8.693148
# 10   8.674475
# 7    8.667174
# 9    8.666174
# 8    8.661433
# 28   8.622887
# 13   8.614751
# 14   8.605642
# 16   8.592785
# 17   8.580926
# 20   8.575490
# 43   8.557294

# %%
#Yukarda görüldüğü üzere IMDB ile çok yakın bir sırlama yaptık. 👍🏻
